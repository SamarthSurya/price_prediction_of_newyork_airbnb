# %%
import pandas as pd

# %%
pd.read_csv("AB_NYC_2019.csv")
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
airbnb = pd.read_csv("AB_NYC_2019.csv")

# %%
import matplotlib.pyplot as plt
import seaborn as sn

# %%
sn.countplot(x="neighbourhood_group", data = airbnb)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/q7/g0ffkfdj64xd39m2kp3cg7hm0000gn/T/ipykernel_40263/2142083244.py in <module>
# ----> 1 sn.countplot(x="neighnourhood_group", data = airbnb)
#       2 plt.show()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py in countplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, dodge, ax, **kwargs)
#    3596         raise ValueError("Cannot pass values for both `x` and `y`")
#    3597
# -> 3598     plotter = _CountPlotter(
#    3599         x, y, hue, data, order, hue_order,
# ...

# %%
sn.countplot(x="neighbourhood_group", data = airbnb)
plt.show()

# %%
sn.barplot(x="neighbourhood_group", y="price", data=airbnb)
plt.show()

# %%
sn.barplot(x="neighbourhood_group", y="price", data=airbnb, ci=False)
plt.show()

# %%
import numpy as np

# %%
plt.hist(airbnb['price'])
plt.xlabel("Price(in USD)")
plt.show
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/q7/g0ffkfdj64xd39m2kp3cg7hm0000gn/T/ipykernel_40263/3238420361.py in <module>
#       1 plt.hist(airbnb['price'])
#       2 plt.xlabel("Price(in USD)")
# ----> 3 PLT.SHOW
#
# NameError: name 'PLT' is not defined

# %%
plt.hist(airbnb['price'])
plt.xlabel("Price(in USD)")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.hist(airbnb['price'], bins(0,600,30))
plt.xlabel("Price(in USD)")
plt.show
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/q7/g0ffkfdj64xd39m2kp3cg7hm0000gn/T/ipykernel_40263/488925671.py in <module>
# ----> 1 plt.hist(airbnb['price'], bins(0,600,30))
#       2 plt.xlabel("Price(in USD)")
#       3 plt.show
#
# NameError: name 'bins' is not defined

# %%
plt.hist(airbnb['price'], bins(0,600,30))
plt.xlabel("Price(in USD)")
plt.show
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/q7/g0ffkfdj64xd39m2kp3cg7hm0000gn/T/ipykernel_40263/2676868082.py in <module>
# ----> 1 plt.hist(airbnb['price'], bins=np.arrange(0,600,30))
#       2 plt.xlabel("Price(in USD)")
#       3 plt.show
#
# ~/opt/anaconda3/lib/python3.9/site-packages/numpy/__init__.py in __getattr__(attr)
#     311                 return Tester
#     312
# --> 313             raise AttributeError("module {!r} has no attribute "
#     314                                  "{!r}".format(__name__, attr))
#     315
#
# AttributeError: module 'numpy' has no attribute 'arrange'

# %%
plt.hist(airbnb['price'], bins = np.arange(0,600,30))
plt.xlabel("Price(in USD)")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.scatter(x=airbnb['price'], y=airbnb["number_of_reviews"])
plt.xlabel('price in USD')
plt.ylabel('number of reviews')
plt.show()

# %%
plt.scatter(x=airbnb['price'], y=airbnb["number_of_reviews"])
plt.xlabel('price in USD')
plt.ylabel('number of reviews')
plt.xlim(0,1500)
plt.show()

# %%
plt.scatter(x=airbnb['price'], y=airbnb["number_of_reviews"], s=5)
plt.xlabel('price in USD')
plt.ylabel('number of reviews')
plt.xlim(0,1500)
plt.show()
